# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load the dataset
df=pd.read_csv('./data/EdgeFile-Pfizer-50.csv')

# %%
df
# Out:
#               Local         Remote Type  Inbound count  Outbound count  \
# 0       1483@2.test   10594@2.test   wl              3               3
# 1       3239@2.test   11029@2.test   wl              1               1
# 2      12037@2.test   14194@2.test   wl              2               6
# 3      23237@2.test    3161@2.test   wl              2               0
# 4       3935@2.test  320922@2.test   wl              9               0
# ...             ...            ...  ...            ...             ...
# 34417   3921@2.test   86222@2.test   wl              2               1
# 34418   3971@2.test   50993@2.test   wl              0               1
# 34419  34885@2.test  115065@2.test   wl              1               0
# 34420  14976@2.test   16653@2.test   wl              1               2
# 34421   3935@2.test    3264@2.test   wl              3               0
#
#                Created      Last inbound     Last outbound  TrustScore  \
# ...
