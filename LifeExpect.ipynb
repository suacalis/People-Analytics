# %%
import plotly.express as px

# %%
df =px.data.gapminder().query("year == 2007")

# %%
df
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...

# %%
px.histogram(df, x="lifeExp",y="pop",marginal = "rug", hover_name="country",color="continent",height =700)
# Out:
# <div>                            <div id="c4df7fc1-0f55-4a8e-b373-c632a9ce16b0" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4df7fc1-0f55-4a8e-b373-c632a9ce16b0")) {                    Plotly.newPlot(                        "c4df7fc1-0f55-4a8e-b373-c632a9ce16b0",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "continent=Asia<br>lifeExp=%{x}<br>sum of pop=%{y}<extra></extra>", "legendgroup": "Asia", "marker": {"color": "#636efa"}, "name": "Asia", "offsetgroup": "Asia", "orientation": "v", "showlegend": true, "type": "histogram", "x": [43.828, 75.635, 64.062, 59.723, 72.961, 82.208, 64.69800000000001, 70.65, 70.964, 59.545, 80.745, 82.603, 72.535, 67.297, 78.623, 77.58800000000001, 71.993, 7
# ...

# %%
px.bar(df, x="continent",y="pop", hover_name="country",color="lifeExp",height =700)
# Out:
# <div>                            <div id="146916ba-f0c6-4176-9374-818495385bf6" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("146916ba-f0c6-4176-9374-818495385bf6")) {                    Plotly.newPlot(                        "146916ba-f0c6-4176-9374-818495385bf6",                        [{"alignmentgroup": "True", "hovertemplate": "<b>%{hovertext}</b><br><br>continent=%{x}<br>pop=%{y}<br>lifeExp=%{marker.color}<extra></extra>", "hovertext": ["Afghanistan", "Albania", "Algeria", "Angola", "Argentina", "Australia", "Austria", "Bahrain", "Bangladesh", "Belgium", "Benin", "Bolivia", "Bosnia and Herzegovina", "Botswana", "Brazil", "Bulgaria", "Burkina Faso", "Burundi", "Cambodia", "Cameroon", "Canada", "Central African Republic", "Chad", "Chile", "Chi
# ...

# %%
px.sunburst(df,path=["continent","country"],values="pop",color="lifeExp",height=700)
# Out:
# <div>
#
#
#             <div id="7a7bb330-11e5-4fbd-b1e1-ef8cf011f596" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7a7bb330-11e5-4fbd-b1e1-ef8cf011f596")) {
#                     Plotly.newPlot(
#                         '7a7bb330-11e5-4fbd-b1e1-ef8cf011f596',
# ...

# %%
px.treemap(df,path=["continent","country"],values="pop",color="lifeExp",height=700)
# Out:
# <div>
#
#
#             <div id="f5f8b8cf-30c8-465b-a7ee-7b03a97d89ff" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f5f8b8cf-30c8-465b-a7ee-7b03a97d89ff")) {
#                     Plotly.newPlot(
#                         'f5f8b8cf-30c8-465b-a7ee-7b03a97d89ff',
# ...

# %%
px.choropleth(df,locations="iso_alpha",hover_name="country",hover_data=df.columns,color="lifeExp",projection="natural earth",height=700)
# Out:
# <div>
#
#
#             <div id="ab63993b-6af6-4ecf-bb23-617067b9d970" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ab63993b-6af6-4ecf-bb23-617067b9d970")) {
#                     Plotly.newPlot(
#                         'ab63993b-6af6-4ecf-bb23-617067b9d970',
# ...

# %%
df =px.data.gapminder()

# %%
px.scatter(df,
           x="gdpPercap",
           y="lifeExp",
           size="pop",
           size_max=65,
           hover_name="country",
           hover_data=df.columns,
           color="continent", 
           animation_frame="year",
           animation_group="country",
           range_y=[20,100],
           log_x=True,
           height=700,
          template="simple_white",
          title="Classic Gamminder Chart",
          labels=dict(gdpPercap="GDP per capita",
                     lifeExp="Life expectancy in years")).update_xaxes(tickprefix="$")
# Out:
# <div>
#
#
#             <div id="802df511-db74-4c8f-ac34-6cb4b8af9c85" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("802df511-db74-4c8f-ac34-6cb4b8af9c85")) {
#                     Plotly.newPlot(
#                         '802df511-db74-4c8f-ac34-6cb4b8af9c85',
# ...
