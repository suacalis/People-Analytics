# %%
#leadership

# %%
import numpy as np
import pandas as pd
import xlrd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
dfs1=pd.read_excel('Automation File - TS Summaries.xlsm', sheet_name='Sheet1')
#df = pd.read_excel('Automation File - TS Summaries.xlsm', sheet_name=None)

# %%
dfs1
# Out:
#                              email                   Name  \
# 0       adesh.goel@trustsphere.com            GOEL, Adesh
# 1      arun.sundar@trustsphere.com  SUNDARAM, Arun Sundar
# 2     brian.lebahn@trustsphere.com          LEBAHN, Brian
# 3     graham.wells@trustsphere.com          WELLS, Graham
# 4      greg.newman@trustsphere.com           NEWMAN, Greg
# 5       jack.welch@trustsphere.com            WELCH, Jack
# 6    kunal.thukral@trustsphere.com         THUKRAL, Kunal
# 7      manish.goel@trustsphere.com           GOEL, Manish
# 8   michael.knight@trustsphere.com        KNIGHT, Michael
# 9      priya.bagga@trustsphere.com           BAGGA, Priya
# 10   roland.turner@trustsphere.com         TURNER, Roland
# 11   shaun.keating@trustsphere.com         KEATING, Shaun
# 12    stan.fischer@trustsphere.com          FISCHER, Stan
# 13     steve.allam@trustsphere.com           ALLAM, Steve
# 14     tim.loveday@trustsphere.com           LOVEDAY, Tim
#
# ...

# %%
#dfs1.to_excel('Automation File - TS Summaries.xlsm', sheet_name='Sheet1')
dfs1.to_excel('states.xlsx', sheet_name='Sheet1', index=False)
