# %% [markdown]
# ## Measure

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline
import plotly.express as px

# %%
# load a joined dataset
df=pd.read_csv('Gen&Hipo2.csv')

# %%
sns.barplot(x="Tenure", y="ncs", hue="Tenure", data=df).set(title = 'Tenure vs ncs');

# %%
sns.barplot(x="Tenure", y="strrels", hue="Tenure", data=df).set(title = 'Tenure vs Stong Relationships');

# %%
sns.barplot(x="Tenure", y="medrels", hue="Tenure", data=df).set(title = 'Tenure vs Medium Relationships');

# %%
sns.barplot(x="Department", y="ncs", hue="Department", data=df).set(title = 'Departments for ncs');

# %%
#sns.pairplot(df, hue="gender",palette="husl").set(title = 'Pair plot for gender');

# %% [markdown]
# ## correlation

# %%
df.corr()
# Out:
#              Address        To  TrustScore     Level    Tenure   totrels  \
# Address     1.000000 -0.011827   -0.017894  0.032019 -0.012236 -0.113113
# To         -0.011827  1.000000   -0.016892 -0.004619 -0.002490  0.004055
# TrustScore -0.017894 -0.016892    1.000000 -0.086865  0.050289  0.069732
# Level       0.032019 -0.004619   -0.086865  1.000000 -0.622670 -0.561237
# Tenure     -0.012236 -0.002490    0.050289 -0.622670  1.000000  0.509838
# totrels    -0.113113  0.004055    0.069732 -0.561237  0.509838  1.000000
# strrels    -0.094574  0.004358    0.123210 -0.658429  0.562278  0.838905
# medrels    -0.110858  0.003611    0.044035 -0.479200  0.448740  0.979008
# ncs        -0.083705  0.001808    0.098368 -0.674079  0.560217  0.935452
#
#              strrels   medrels       ncs
# Address    -0.094574 -0.110858 -0.083705
# To          0.004358  0.003611  0.001808
# TrustScore  0.123210  0.044035  0.098368
# Level      -0.658429 -0.479200 -0.674079
# ...

# %%
sns.heatmap(df.corr())

# %%
sns.jointplot("Level", "medrels", data=df, kind="hex");

# %%
sns.lineplot("DateTime", "medrels",data=df);

# %%
df[['Address']].plot(figsize=(20,10), linewidth=1, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
plt.figure(figsize=(20,9)) 
#sns.lineplot(data=df, x='DateTime',y='Address')
sns.lineplot("DateTime", "Address",hue='ncs',data=df);

# %%
df['DateTime'] = df['DateTime'].dt.strftime('%d/%m/%Y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-455a105abb35> in <module>
# ----> 1 df['DateTime'] = df['DateTime'].dt.strftime('%d/%m/%Y')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
# ...

# %%
start=min(df['DateTime'])
end=max(df['DateTime'])

# %%
start
# Out:
# '1/30/2020 0:59'

# %%
end
# Out:
# '4/28/2020 8:59'
